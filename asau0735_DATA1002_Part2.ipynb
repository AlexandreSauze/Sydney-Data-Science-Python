# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexandreSauze/Sydney-Data-Science-Python/blob/main/asau0735_DATA1002_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  # import panda functions
import numpy as np  # import statistic and math functions
import matplotlib as plt

data = pd.read_csv('SDG_goal3_clean (1).csv')  # import csv data into a Panda Data Frame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 28 columns):
#  #   Column                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                           --------------  -----
#  0   Country                                                                                                                          163 non-null    object
#  1   Year                                                                                                                             163 non-null    int64
#  2   Region                                                                                                                           163 non-null    object
#  3   Maternal mortality ratio                                                                                                         163 non-null    int64
#  4   Proportion of births attended by skilled health personnel (%)                                                                    163 non-null    float64
#  5   Infant mortality rate (deaths per 1,000 live births):::BOTHSEX                                                                   163 non-null    float64
#  6   Infant mortality rate (deaths per 1,000 live births):::MALE                                                                      163 non-null    float64
#  7   Infant mortality rate (deaths per 1,000 live births):::FEMALE                                                                    163 non-null    float64
#  8   Under-five mortality rate, by sex (deaths per 1,000 live births):::BOTHSEX                                                       163 non-null    float64
#  9   Under-five mortality rate, by sex (deaths per 1,000 live births):::MALE                                                          163 non-null    float64
#  10  Under-five mortality rate, by sex (deaths per 1,000 live births):::FEMALE                                                        163 non-null    float64
#  11  Neonatal mortality rate (deaths per 1,000 live births)                                                                           163 non-null    float64
#  12  Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability):::BOTHSEX     163 non-null    float64
#  13  Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability):::MALE        163 non-null    float64
#  14  Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability):::FEMALE      163 non-null    float64
#  15  Fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  163 non-null    float64
#  16  Fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease    163 non-null    float64
#  17  Suicide mortality rate, by sex (deaths per 100,000 population):::BOTHSEX                                                         163 non-null    float64
#  18  Suicide mortality rate, by sex (deaths per 100,000 population):::MALE                                                            163 non-null    float64
#  19  Suicide mortality rate, by sex (deaths per 100,000 population):::FEMALE                                                          163 non-null    float64
#  20  Death rate due to road traffic injuries, by sex (per 100,000 population):::BOTHSEX                                               163 non-null    float64
#  21  Death rate due to road traffic injuries, by sex (per 100,000 population):::MALE                                                  163 non-null    float64
#  22  Death rate due to road traffic injuries, by sex (per 100,000 population):::FEMALE                                                163 non-null    float64
#  23  Adolescent birth rate (per 1,000 women aged 15-19 years)                                                                         163 non-null    float64
#  24  Universal health coverage (UHC) service coverage index                                                                           163 non-null    int64
#  25  Health worker density, by type of occupation (per 10,000 population)::PHYSICIAN                                                  163 non-null    float64
#  26  Health worker density, by type of occupation (per 10,000 population)::NURSEMIDWIFE                                               163 non-null    float64
#  27  Health worker density, by type of occupation (per 10,000 population)::PHARMACIST                                                 163 non-null    float64
# dtypes: float64(23), int64(3), object(2)
# memory usage: 35.8+ KB

# %%
data.isna().sum()  # Check if there are any Nans in each column
data.isnull().sum()  # Check if there are any blank spaces in each column
# Out:
# Country                                                                                                                            0
# Year                                                                                                                               0
# Region                                                                                                                             0
# Maternal mortality ratio                                                                                                           0
# Proportion of births attended by skilled health personnel (%)                                                                      0
# Infant mortality rate (deaths per 1,000 live births):::BOTHSEX                                                                     0
# Infant mortality rate (deaths per 1,000 live births):::MALE                                                                        0
# Infant mortality rate (deaths per 1,000 live births):::FEMALE                                                                      0
# Under-five mortality rate, by sex (deaths per 1,000 live births):::BOTHSEX                                                         0
# Under-five mortality rate, by sex (deaths per 1,000 live births):::MALE                                                            0
# Under-five mortality rate, by sex (deaths per 1,000 live births):::FEMALE                                                          0
# Neonatal mortality rate (deaths per 1,000 live births)                                                                             0
# Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability):::BOTHSEX       0
# Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability):::MALE          0
# Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability):::FEMALE        0
# Fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease    0
# Fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease      0
# Suicide mortality rate, by sex (deaths per 100,000 population):::BOTHSEX                                                           0
# Suicide mortality rate, by sex (deaths per 100,000 population):::MALE                                                              0
# Suicide mortality rate, by sex (deaths per 100,000 population):::FEMALE                                                            0
# Death rate due to road traffic injuries, by sex (per 100,000 population):::BOTHSEX                                                 0
# Death rate due to road traffic injuries, by sex (per 100,000 population):::MALE                                                    0
# Death rate due to road traffic injuries, by sex (per 100,000 population):::FEMALE                                                  0
# Adolescent birth rate (per 1,000 women aged 15-19 years)                                                                           0
# Universal health coverage (UHC) service coverage index                                                                             0
# Health worker density, by type of occupation (per 10,000 population)::PHYSICIAN                                                    0
# Health worker density, by type of occupation (per 10,000 population)::NURSEMIDWIFE                                                 0
# Health worker density, by type of occupation (per 10,000 population)::PHARMACIST                                                   0
# dtype: int64

# %%
df = data[["Country",	"Year",	"Region", "Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability):::BOTHSEX", "Fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease", "Fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"]]
#UD.rename(columns={"Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability):::BOTHSEX": "Probability", "Fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": "Fraction D", "Fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": "Fraction C"}, inplace=True)
#UD["Region"].unique()
df = df.rename(columns={"Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability):::BOTHSEX": "Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability)"})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 6 columns):
#  #   Column                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                           --------------  -----
#  0   Country                                                                                                                          163 non-null    object
#  1   Year                                                                                                                             163 non-null    int64
#  2   Region                                                                                                                           163 non-null    object
#  3   Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability)               163 non-null    float64
#  4   Fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  163 non-null    float64
#  5   Fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease    163 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 7.8+ KB

# %%
UD = df.to_dict('records')
UD
gas = {}  # Group Aggregate Summary
for row in UD:
  if row["Region"] not in gas:
    gas[row["Region"]] = {"Mor": [], "FD": [], "FC": []}
  gas[row["Region"]]["Mor"].append(row["Mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease (probability)"])
  gas[row["Region"]]["FD"].append(row["Fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"])
  gas[row["Region"]]["FC"].append(row["Fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"])

nc = {"Region" : list(gas),"median mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "mean mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "sd mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "max mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "min mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "median fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "mean fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "sd fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "max fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "min fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "median fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "mean fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "sd fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "max fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": [], "min fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease": []}
for reg in gas:
  nc["median mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(np.median(gas[reg]["Mor"]))
  nc["mean mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(np.mean(gas[reg]["Mor"]))
  nc["sd mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(np.std(gas[reg]["Mor"]))
  nc["max mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(max(gas[reg]["Mor"]))
  nc["min mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(min(gas[reg]["Mor"]))

  nc["median fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(np.median(gas[reg]["FD"]))
  nc["mean fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(np.mean(gas[reg]["FD"]))
  nc["sd fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(np.std(gas[reg]["FD"]))
  nc["max fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(max(gas[reg]["FD"]))
  nc["min fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(min(gas[reg]["FD"]))

  nc["median fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(np.median(gas[reg]["FC"]))
  nc["mean fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(np.mean(gas[reg]["FC"]))
  nc["sd fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(np.std(gas[reg]["FC"]))
  nc["max fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(max(gas[reg]["FC"]))
  nc["min fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease"].append(min(gas[reg]["FC"]))
ndf = pd.DataFrame(nc)
ndf
# Out:
#      Region  \
# 0    Europe
# 1      Asia
# 2   Oceania
# 3  Americas
# 4    Africa
#
#    median mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                              18.40
# 1                                              25.25
# 2                                              12.35
# 3                                              12.90
# 4                                              23.60
#
#    mean mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                          18.637647
# 1                                          24.404167
# 2                                          17.470000
# 3                                          15.091667
# 4                                          22.662500
#
#    sd mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                           6.671202
# 1                                           8.832727
# 2                                          12.717315
# 3                                           5.120296
# 4                                           3.426346
#
#    max mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                               35.3
# 1                                               41.6
# 2                                               53.0
# 3                                               28.7
# 4                                               26.4
#
#    min mortality rate attributed to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                                9.2
# 1                                                8.4
# 2                                                9.3
# 3                                                9.8
# 4                                               14.8
#
#    median fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                             0.0230
# 1                                             0.0485
# 2                                             0.0385
# 3                                             0.1015
# 4                                             0.0940
#
#    mean fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                           0.026624
# 1                                           0.069062
# 2                                           0.072800
# 3                                           0.112417
# 4                                           0.149625
#
#    sd fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                           0.016690
# 1                                           0.058661
# 2                                           0.070428
# 3                                           0.046852
# 4                                           0.099668
#
#    max fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                              0.081
# 1                                              0.270
# 2                                              0.216
# 3                                              0.198
# 4                                              0.327
#
#    min fraction of deaths due to diabetes, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                              0.005
# 1                                              0.015
# 2                                              0.031
# 3                                              0.056
# 4                                              0.082
#
#    median fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                             0.3220
# 1                                             0.2165
# 2                                             0.3845
# 3                                             0.3325
# 4                                             0.1910
#
#    mean fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                           0.315765
# 1                                           0.227396
# 2                                           0.361700
# 3                                           0.328500
# 4                                           0.229625
#
#    sd fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                           0.072969
# 1                                           0.096633
# 2                                           0.075403
# 3                                           0.043026
# 4                                           0.069835
#
#    max fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease  \
# 0                                              0.469
# 1                                              0.474
# 2                                              0.426
# 3                                              0.396
# 4                                              0.333
#
#    min fraction of deaths due to cancer, among deaths due to cardiovascular disease, cancer, diabetes or chronic respiratory disease
# 0                                              0.148
# 1                                              0.102
# 2                                              0.167
# 3                                              0.253
# 4                                              0.153

# %%
def f(a_list, a_index):
     if a_index >= 0:
        z = a_list[a_index]
        return z
     else:
         raise ValueError

def entry5(some_list):
     try:
        print(f(some_list, 5))
     except ValueError:
        print("Got it")

mylist = [2,3,4]
try:
   entry5(mylist)
   print("Success")
except IndexError:
   print("Index not suitable")
except ValueError:
   print("Value not suitable")
print("Finished")
# Out:
# Index not suitable
# Finished
